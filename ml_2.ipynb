# %% [markdown]
# <a href="https://colab.research.google.com/github/niteshkumar0205/ml_1/blob/main/ml_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#seaborn and #matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset("iris")

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
plt.plot(data['sepal_width'])

plt.show()

# %%
plt.plot(data['sepal_length'])

plt.show()

# %%
plt.plot(data['petal_width'])

plt.show()

# %%
plt.plot(data['petal_length'])

plt.show()

# %%
plt.plot(data['sepal_width'])
plt.xlabel("Indexes")
plt.ylabel("sepal width")

plt.show()

# %%
plt.figure(figsize = (10,5))
plt.plot(data['sepal_width'], color = "red", label = "sepal width")
plt.plot(data['sepal_length'], color = "green", label = "sepal length")
plt.xlabel("Indexes")
plt.ylabel(" sepal counts")

plt.title("sepal graph", fontsize = 27)

plt.show()

# %%
plt.plot(data['petal_width'], color = "red", label = "petal width")
plt.plot(data['petal_length'], color = "green", label = "petal length")
plt.xlabel("Indexes")
plt.ylabel(" petal counts")

plt.title("petal graph", fontsize = 27)

plt.show()

# %%
plt.figure(figsize = (10,5))
plt.grid()
plt.plot(data['sepal_width'], color = "red", label = "sepal width", linestyle = "--")
plt.plot(data['sepal_length'], color = "green", label = "sepal length", marker = "o")
plt.xlabel("Indexes")
plt.ylabel(" sepal counts")

plt.title("sepal graph", fontsize = 27)

plt.show()

# %%
plt.bar(data["species"],data["sepal_length"])
plt.bar(data["species"],data["sepal_width"])
plt.show()

# %%
#tips data set

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
plt.bar(tips["day"],tips["total_bill"])
plt.show()

# %%
plt.barh(tips["day"],tips["total_bill"])
plt.show()

# %%
plt.hist(tips["total_bill"], edgecolor ="black")
plt.show()

# %%
day = tips.groupby('day')["total_bill"].sum().reset_index()
day
# Out:
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %%
x = day["day"]

y = day["total_bill"]

# %%
explode = [0,0,0,0.1]
plt.pie(y,labels = x , explode = explode ,autopct='%1.1f%%',colors = ['red','green','blue','yellow'],
        wedgeprops = {'edgecolor': 'black'},shadow = True, startangle=90)
plt.show()

# %%
plt.scatter(tips["total_bill"],tips["tip"])
plt.title("scatterplot")
plt.xlabel("total bill")
plt.ylabel("tip")

plt.show()

# %%
tips['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# 1      4
# Name: size, dtype: int64

# %%
plt.scatter(tips["total_bill"],tips["tip"],s = 100 , c = tips['size'])
plt.title("scatterplot")
plt.xlabel("total bill")
plt.ylabel("tip")
cbar = plt.colorbar()
cbar.set_label("size")


plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-white')

gender = sns.countplot(tips['sex'])

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.distplot(tips["total_bill"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips['total_bill'],hist = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
#Scatterplot using seaborn

sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, hue = 'size', palette= 'summer')

# %%
#Swarmplot

sns.swarmplot(x = 'sex', y = 'total_bill', data = tips)

# %%
#Strip plot

sns.stripplot(x = 'day', y = 'tip', data = tips, hue = 'sex')

# %%
#Voiline Plot

sns.violinplot(x = 'day', y = 'tip', data = tips, hue = 'sex', split = True)

# %%
#Boxplot

sns.boxplot(x = 'day', y = 'tip', data = tips, hue = 'sex')
